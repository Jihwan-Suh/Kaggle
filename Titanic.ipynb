# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test['Survived']=np.nan

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# Survived       0 non-null float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 39.3+ KB

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# 3  27.0      0      0   315154   8.6625   NaN        S       NaN
# 4  22.0      1      1  3101298  12.2875   NaN        S       NaN

# %%
all = pd.concat([train, test])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
all.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
all.isna().sum() #결측값 개수 확인
# Out:
# Age             263
# Cabin          1014
# Embarked          2
# Fare              1
# Name              0
# Parch             0
# PassengerId       0
# Pclass            0
# Sex               0
# SibSp             0
# Survived        418
# Ticket            0
# dtype: int64

# %%
Survived = all['Survived'].value_counts()
print("Survived counting: ")
print(Survived)

sns.countplot(data=all, x='Survived')
# Out:
# Survived counting:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
Sex = all['Sex'].value_counts()
print("Sex counting: ")
print(Sex)

sns.countplot(data=all, x='Sex')
# Out:
# Sex counting:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
sns.countplot(data=all, x='Sex',hue='Survived') #남자들이 많이 죽은것으로 보입니다.

# %%
Pclass = all['Pclass'].value_counts()
print("Pclass counting: ")
print(Pclass)
sns.countplot(data=all, x='Pclass')
# Out:
# Pclass counting:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
sns.countplot(data=all, x='Pclass',hue='Survived')

# %%
all.loc[(all['Pclass']==1) & (all['Sex'] =='male'), 'PclassSex'] = 'P1Male'
all.loc[(all['Pclass']==2) & (all['Sex'] =='male'), 'PclassSex'] = 'P2Male'
all.loc[(all['Pclass']==3) & (all['Sex'] =='male'), 'PclassSex'] = 'P3Male'
all.loc[(all['Pclass']==1) & (all['Sex'] =='female'), 'PclassSex'] = 'P1Female'
all.loc[(all['Pclass']==2) & (all['Sex'] =='female'), 'PclassSex'] = 'P2Female'
all.loc[(all['Pclass']==3) & (all['Sex'] =='female'), 'PclassSex'] = 'P3Female'

# %%
all['Surname'] = all['Name'].apply(lambda e: e.split(',')[0])
all['Title'] = all['Name'].apply(lambda e: e.split(',')[1])
all['Title'] = all['Title'].apply(lambda e: e.split('.')[0])

# %%
all
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %%
all['Fsize']=all['SibSp']+all['Parch']+1

# %%
all
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# ...

# %%
sns.countplot(data=all, x='Fsize',hue='Survived') #혼자 탄 사람들이 죽을확률이 높았다.
